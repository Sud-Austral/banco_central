# %%
import pandas as pd
import time
import os
import git
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.action_chains import ActionChains

# %%
url = "https://si3.bcentral.cl/siete/"

# %%
def getDriver(link):
    
    options = Options()
    # options.log.level = "trace"
    # options.add_argument("--headless")
    options.set_preference("browser.download.manager.showWhenStarting", False)
    options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv")
    driver = webdriver.Firefox(options=options)
    driver.set_page_load_timeout("60")
    driver.get(link)
    
    return driver

# %%
def diccionario(num, name):
    
    diccionario = {}
    
    diccionario["Código"] = num
    diccionario["Carpeta"] = name
    
    return diccionario

# %%
def diccionario1(num, name, num1, name1):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    
    return diccionario

# %%
def diccionario2(num, name, num1, name1, num2, name2):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    
    return diccionario

# %%
def diccionario3(num, name, num1, name1, num2, name2, num3, name3):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    
    return diccionario

# %%
def diccionario4(num, name, num1, name1, num2, name2, num3, name3, num4, name4):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    diccionario["Código (sub4)"] = num4
    diccionario["Carpeta (sub4)"] = name4
    
    return diccionario

# %%
def diccionario5(num, name, num1, name1, num2, name2, num3, name3, num4, name4, num5, name5):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    diccionario["Código (sub4)"] = num4
    diccionario["Carpeta (sub4)"] = name4
    diccionario["Código (sub5)"] = num5
    diccionario["Carpeta (sub5)"] = name5
    
    return diccionario

# %%
def diccionario6(num, name, num1, name1, num2, name2, num3, name3, num4, name4, num5, name5, num6, name6):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    diccionario["Código (sub4)"] = num4
    diccionario["Carpeta (sub4)"] = name4
    diccionario["Código (sub5)"] = num5
    diccionario["Carpeta (sub5)"] = name5
    diccionario["Código (sub6)"] = num6
    diccionario["Carpeta (sub6)"] = name6
    
    return diccionario

# %%
def diccionario7(num, name, num1, name1, num2, name2, num3, name3, num4, name4, num5, name5, num6, name6, num7, name7):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    diccionario["Código (sub4)"] = num4
    diccionario["Carpeta (sub4)"] = name4
    diccionario["Código (sub5)"] = num5
    diccionario["Carpeta (sub5)"] = name5
    diccionario["Código (sub6)"] = num6
    diccionario["Carpeta (sub6)"] = name6
    diccionario["Código (sub7)"] = num7
    diccionario["Carpeta (sub7)"] = name7
    
    return diccionario

# %%
def diccionario8(num, name, num1, name1, num2, name2, num3, name3, num4, name4, num5, name5, num6, name6, num7, name7, num8, name8):
    
    diccionario = {}
    
    diccionario["Código (sub)"] = num
    diccionario["Carpeta (sub)"] = name
    diccionario["Código (sub1)"] = num1
    diccionario["Carpeta (sub1)"] = name1
    diccionario["Código (sub2)"] = num2
    diccionario["Carpeta (sub2)"] = name2
    diccionario["Código (sub3)"] = num3
    diccionario["Carpeta (sub3)"] = name3
    diccionario["Código (sub4)"] = num4
    diccionario["Carpeta (sub4)"] = name4
    diccionario["Código (sub5)"] = num5
    diccionario["Carpeta (sub5)"] = name5
    diccionario["Código (sub6)"] = num6
    diccionario["Carpeta (sub6)"] = name6
    diccionario["Código (sub7)"] = num7
    diccionario["Carpeta (sub7)"] = name7
    diccionario["Código (sub8)"] = num8
    diccionario["Carpeta (sub8)"] = name8
    
    return diccionario

# %%
def descarga():
    driver = getDriver(url)

    qLink = driver.find_elements_by_xpath("/html/body/div[3]/div/div/div/div/div[2]/a")
    len(qLink)

    # number = []
    # folder = []
    
    dic = []

    for i in range(len(qLink)):
    # for i in range(3,4):

        title = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[" + str(i + 1) +"]/div/div[1]/h3")
        t = title.text
        _t = title.text

        # number.append(i+1)
        # folder.append(t)
        
        dix = diccionario(i+1, t)
        dic.append(dix.copy())

        t = str(i + 1)

        # print(t)

        if (os.path.isdir('../' + t)):
            pass

        else:
            os.mkdir('../' + t)

        btn = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[" + str(i + 1) +"]/div/div[2]/a")
        btn.click()

        try:
            activeElement = driver.find_elements_by_xpath("//*[@class='icon-mt icon-mt-plus active']")

            for h in range(len(activeElement)):

                driver.execute_script("arguments[0].click();", activeElement[(len(activeElement)-h)-1])


        except:
            pass

        # qMenu = driver.find_elements_by_xpath("/html/body/div[3]/nav/div[2]/ul/li/a")
        #  print(len(qMenu))

        # number1 = []
        # folder1 = []

        #nsub1 = []
        # fsub1 = []
        
        dic1 = []

        for j in range(20): # 20 # 1 (VEINTE NÚMERO 1)
            # print(j)
            try:
                sub = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/a")
                s = sub.text
                _s = sub.text

                # print(s)

                principal = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/a").get_attribute('onclick') 
                _principal = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/a")

                _p = _principal.text

                if (principal != None):
                    # print("DESCARGAR TABLA")                        
                    _principal.click()

                    # textOption.click()

                    frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                    # print(len(frequency))

                    for r in range(len(frequency)):
                        frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                        # print("Cantidad: " + str(len(frequency)))
                        f = frequency[r].text
                        frequency[r].click()


                        # print(f)

                        freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                        if(len(freq) == 3):
                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                            for sd in range(len(initial)):
                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                date1 = initial[sd].text

                                initial[sd].click()

                                currentUrl = driver.current_url

                                dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                df = dataTable[0]
                                del df["Sel."]

                                # print('SUB 1: Files/' + t + '/' + str(_p) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                df.transpose().to_excel('../' + t + '/' + str(_p) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                path = '../' + t + '/' + str(_p) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                tables(path)
                                # print("¡Guardado!")

                        else:
                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                            date1 = initial[0].text

                            initial[0].click()

                            final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                            maxDate = len(final)
                            date2 = final[maxDate-1].text

                            final[maxDate-1].click()

                            currentUrl = driver.current_url

                            dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                            df = dataTable[0]
                            del df["Sel."]

                            # print('SUB 1: Files/' + t + '/' + str(_p) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                            df.transpose().to_excel('../' + t + '/' + str(_p) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')

                            path = '../' + t + '/' + str(_p) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                            tables(path)
                            # print("¡Guardado!")

                else:
                    # print("CARPETA")

                    if(s != ""):
                        # number1.append(j+1)
                        # folder1.append(s)

                        # nsub1.append(number)
                        # fsub1.append(folder)
                        
                        dix1 = diccionario1(i+1, _t, j+1, _s)
                        dic1.append(dix1.copy())

                        s = str(j + 1)
                        # print(t)

                        if (os.path.isdir('../' + t + '/' + s)):
                            pass

                        else:
                            os.mkdir('../' + t + '/' + s)
                    # os.mkdir('Files/' + t + '/' + s)
                    _principal.click()

                    # number2 = []
                    # folder2 = []
                    
                    # nsub2 = []
                    # fsub2 = []
                    
                    dic2 = []
        
                    for k in range(20): # 20 # 2 (VEINTE NÚMERO 2)
                        # print(k)
                        try:
                            sub1 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/a")
                            s1 = sub1.text
                            _s1 = sub1.text

                            # print(s1)

                            principal1 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/a").get_attribute('onclick')
                            _principal1 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/a")

                            _p1 = _principal1.text

                            if (principal1 != ""):
                                # print("DESCARGAR TABLA")
                                _principal1.click()

                                # textOption.click()

                                frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                # print(len(frequency))

                                for r in range(len(frequency)):
                                    frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                    # print("Cantidad: " + str(len(frequency)))
                                    f = frequency[r].text
                                    frequency[r].click()


                                    # print(f)

                                    freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                    if(len(freq) == 3):
                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                        for sd in range(len(initial)):
                                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                            date1 = initial[sd].text

                                            initial[sd].click()

                                            currentUrl = driver.current_url

                                            dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                            df = dataTable[0]
                                            del df["Sel."]

                                            # print('SUB 2: Files/' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')
                                            df.transpose().to_excel('../' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                            path1 = '../' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                            tables(path1)
                                            # print("¡Guardado!")

                                    else:
                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                        date1 = initial[0].text

                                        initial[0].click()

                                        final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                        maxDate = len(final)
                                        date2 = final[maxDate-1].text

                                        final[maxDate-1].click()

                                        currentUrl = driver.current_url

                                        dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                        df = dataTable[0]
                                        del df["Sel."]

                                        # print('SUB 2: Files/' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                                        df.transpose().to_excel('../' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')

                                        path1 = '../' + t + '/' + s + '/' + str(_p1) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                        tables(path1)
                                        # print("¡Guardado!")

                            else:
                                # print("CARPETA")

                                if(s1 != ""):
                                    # number2.append(k+1)
                                    # folder2.append(s1)
                                    
                                    # nsub2.append(number1)
                                    # fsub2.append(number1)
                                    
                                    dix2 = diccionario2(i+1, _t, j+1, _s, k+1, _s1)
                                    dic2.append(dix2.copy())
                                    
                                    s1 = str(k + 1)
                                    # print(t)

                                    if (os.path.isdir('../' + t + '/' + s + '/' + s1)):
                                        pass

                                    else:
                                        os.mkdir('../' + t + '/' + s + '/' + s1)
                                #os.mkdir('Files/' + t + '/' + s + '/' + s1)
                                _principal1.click()

                                # number3 = []
                                # folder3 = []
                                
                                # nsub3 = []
                                # fsub3 = []
                                
                                dic3 = []
        
                                for l in range(20): # 20 # 3 (VEINTE NÚMERO 3)
                                    # print(l)
                                    try:
                                        sub2 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/a")
                                        s2 = sub2.text
                                        _s2 = sub2.text

                                        # print(s2)

                                        principal2 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/a").get_attribute('onclick')
                                        _principal2 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/a")

                                        _p2 = _principal2.text

                                        if (principal2 != ""):
                                            # print("DESCARGAR TABLA")
                                            _principal2.click()

                                            # textOption.click()

                                            frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                            # print(len(frequency))

                                            for r in range(len(frequency)):
                                                frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                # print("Cantidad: " + str(len(frequency)))
                                                f = frequency[r].text
                                                frequency[r].click()


                                                # print(f)

                                                freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                if(len(freq) == 3):
                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                    for sd in range(len(initial)):
                                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                        date1 = initial[sd].text

                                                        initial[sd].click()

                                                        currentUrl = driver.current_url

                                                        dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                        df = dataTable[0]
                                                        del df["Sel."]

                                                        # print('SUB 3: Files/' + t + '/' + '/' + s + '/' + s1 + '/' + str(_p2) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                        df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + '/' + str(_p2) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                        path2 = '../' + t + '/' + s + '/' + s1 + '/' + '/' + str(_p2) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                        tables(path2)
                                                        # print("¡Guardado!")

                                                else:
                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                    date1 = initial[0].text

                                                    initial[0].click()

                                                    final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                    maxDate = len(final)
                                                    date2 = final[maxDate-1].text

                                                    final[maxDate-1].click()

                                                    currentUrl = driver.current_url

                                                    dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                    df = dataTable[0]
                                                    del df["Sel."]

                                                    # print('SUB 3: Files/' + t + '/' + s + '/' + s1 + '/' + str(_p2) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')

                                                    df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + str(_p2) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')

                                                    path2 = '../' + t + '/' + s + '/' + s1 + '/' + str(_p2) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                    tables(path2)
                                                    # print("¡Guardado!")

                                        else:
                                            # print("CARPETA")

                                            if(s2 != ""):
                                                # number3.append(l+1)
                                                # folder3.append(s2)
                                                
                                                # nsub3.append(number2)
                                                # fsub3.append(number2)
                                                
                                                dix3 = diccionario3(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2)
                                                dic3.append(dix3.copy())

                                                s2 = str(l + 1)
                                                # print(t)

                                                if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2)):
                                                    pass

                                                else:
                                                    os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2)

                                            _principal2.click()

                                            # os.mkdir('Files/' + t + '/' + s + '/' + s1 + '/' + s2)

                                            # number4 = []
                                            # folder4 = []
                                            
                                            # nsub4 = []
                                            # fsub4 = []
                                            
                                            dic4 = []
        
                                            for m in range(20): # 20 # 4 (VEINTE NÚMERO 4)
                                                # print(l)
                                                try:
                                                    sub3 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/a")
                                                    s3 = sub3.text
                                                    _s3 = sub3.text

                                                    # print(s3)

                                                    principal3 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/a").get_attribute('onclick')
                                                    _principal3 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/a")

                                                    _p3 = _principal3.text

                                                    if (principal3 != ""):
                                                        # print("DESCARGAR TABLA")
                                                        _principal3.click()

                                                        # textOption.click()

                                                        frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                                        # print(len(frequency))

                                                        for r in range(len(frequency)):
                                                            frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                            # print("Cantidad: " + str(len(frequency)))
                                                            f = frequency[r].text
                                                            frequency[r].click()


                                                            # print(f)

                                                            freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                            if(len(freq) == 3):
                                                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                                for sd in range(len(initial)):
                                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                    date1 = initial[sd].text

                                                                    initial[sd].click()

                                                                    currentUrl = driver.current_url

                                                                    dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                    df = dataTable[0]
                                                                    del df["Sel."]


                                                                    # print('SUB 4: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                    df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                    path3 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                                    tables(path3)
                                                                    # print("¡Guardado!")

                                                            else:
                                                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                date1 = initial[0].text

                                                                initial[0].click()

                                                                final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                                maxDate = len(final)
                                                                date2 = final[maxDate-1].text

                                                                final[maxDate-1].click()

                                                                currentUrl = driver.current_url

                                                                dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                df = dataTable[0]
                                                                del df["Sel."]

                                                                # print('SUB 4: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')


                                                                df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                                                                path3 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + str(_p3) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                                tables(path3)
                                                                # print("¡Guardado!")

                                                    else:
                                                        # print("CARPETA")

                                                        if(s3 != ""):
                                                            # number4.append(m + 1)
                                                            # folder4.append(s3)
                                                            
                                                            # nsub4.append(number3)
                                                            # fsub4.append(number3)
                                                            
                                                            dix4 = diccionario4(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2, m+1, _s3)
                                                            dic4.append(dix4.copy())

                                                            s3 = str(m + 1)
                                                            # print(t)

                                                            if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3)):
                                                                pass

                                                            else:
                                                                os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3)

                                                        _principal3.click()


                                                        # number5 = []
                                                        # folder5 = []
                                                        
                                                        # nsub5 = []
                                                        # fsub5 = []
                                                        
                                                        dic5 = []

                                                        for n in range(20): # 20 # 5 (VEINTE NÚMERO 5)
                                                            # print(l)
                                                            try:
                                                                sub4 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/a")
                                                                s4 = sub4.text
                                                                _s4 = sub4.text

                                                                # print(s4)

                                                                principal4 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/a").get_attribute('onclick')
                                                                _principal4 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/a")

                                                                _p4 = _principal4.text

                                                                if (principal4 != ""):
                                                                    # print("DESCARGAR TABLA")
                                                                    _principal4.click()

                                                                    # textOption.click()

                                                                    frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                                                    # print(len(frequency))

                                                                    for r in range(len(frequency)):
                                                                        frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                                        # print("Cantidad: " + str(len(frequency)))
                                                                        f = frequency[r].text
                                                                        frequency[r].click()


                                                                        # print(f)

                                                                        freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                                        if(len(freq) == 3):
                                                                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                                            for sd in range(len(initial)):
                                                                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                date1 = initial[sd].text

                                                                                initial[sd].click()

                                                                                currentUrl = driver.current_url

                                                                                dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                df = dataTable[0]
                                                                                del df["Sel."]

                                                                                # print('SUB 5: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                                df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                                path4 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                                                tables(path4)
                                                                                # print("¡Guardado!")

                                                                        else:
                                                                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                            date1 = initial[0].text

                                                                            initial[0].click()

                                                                            final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                                            maxDate = len(final)
                                                                            date2 = final[maxDate-1].text

                                                                            final[maxDate-1].click()

                                                                            currentUrl = driver.current_url

                                                                            dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                            df = dataTable[0]
                                                                            del df["Sel."]

                                                                            # print(' SUB 5: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')


                                                                            df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')

                                                                            path4 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + str(_p4) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                                            tables(path4)
                                                                            # print("¡Guardado!")

                                                                else:
                                                                    # print("CARPETA")

                                                                    if(s4 != ""):
                                                                        # number5.append(n+1)
                                                                        # folder5.append(s4)
                                                                        
                                                                        # nsub5.append(number4)
                                                                        # fsub5.append(number4)
                                                                        
                                                                        dix5 = diccionario5(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2, m+1, _s3, n+1, _s4)
                                                                        dic5.append(dix5.copy())

                                                                        s4 = str(n + 1)
                                                                        # print(t)

                                                                        if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4)):
                                                                            pass

                                                                        else:
                                                                            os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4)

                                                                    _principal4.click()

                                                                    # number6 = []
                                                                    # folder6 = []
                                                                    
                                                                    # nsub6 = []
                                                                    # fsub6 = []
                                                                    
                                                                    dic6 = []

                                                                    for o in range(20): # 20 # 6 (VEINTE NÚMERO 6)
                                                                        # print(l)
                                                                        try:
                                                                            sub5 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/a")
                                                                            s5 = sub5.text
                                                                            _s5 = sub5.text

                                                                            # print(s5)

                                                                            principal5 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/a").get_attribute('onclick')
                                                                            _principal5 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/a")

                                                                            _p5 = _principal5.text

                                                                            if (principal5 != ""):
                                                                                # print("DESCARGAR TABLA")

                                                                                _principal5.click()

                                                                                # textOption.click()

                                                                                frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                                                                # print(len(frequency))

                                                                                for r in range(len(frequency)):
                                                                                    frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                                                    # print("Cantidad: " + str(len(frequency)))
                                                                                    f = frequency[r].text
                                                                                    frequency[r].click()


                                                                                    # print(f)

                                                                                    freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                                                    if(len(freq) == 3):
                                                                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                                                        for sd in range(len(initial)):
                                                                                            initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                            date1 = initial[sd].text

                                                                                            initial[sd].click()

                                                                                            currentUrl = driver.current_url

                                                                                            dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                            df = dataTable[0]
                                                                                            del df["Sel."]

                                                                                            # print('SUB 6: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                                            df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')
                                                                                            path5 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                                                            tables(path5)
                                                                                            # print("¡Guardado!")

                                                                                    else:
                                                                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                        date1 = initial[0].text

                                                                                        initial[0].click()

                                                                                        final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                                                        maxDate = len(final)
                                                                                        date2 = final[maxDate-1].text

                                                                                        final[maxDate-1].click()

                                                                                        currentUrl = driver.current_url

                                                                                        dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                        df = dataTable[0]
                                                                                        del df["Sel."]

                                                                                        # print('SUB 6: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')


                                                                                        df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                                                                                        path5 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + str(_p5) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                                                        tables(path5)
                                                                                        # print("¡Guardado!")

                                                                            else:
                                                                                # print("CARPETA")

                                                                                if(s5 != ""):
                                                                                    # number6.append(o+1)
                                                                                    # folder6.append(s5)
                                                                                    
                                                                                    # nsub6.append(number5)
                                                                                    # fsub6.append(number5)
                                                                                    
                                                                                    dix6 = diccionario6(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2, m+1, _s3, n+1, _s4, o+1, _s5)
                                                                                    dic6.append(dix6.copy())

                                                                                    s5 = str(o + 1)
                                                                                    # print(t)

                                                                                    if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5)):
                                                                                        pass

                                                                                    else:
                                                                                        os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5)

                                                                                _principal5.click()

                                                                                # number7 = []
                                                                                # folder7 = []
                                                                                
                                                                                # nsub7 = []
                                                                                # fsub7 = []
                                                                                
                                                                                dic7 = []

                                                                                for p in range(20): # 20 # 7 (VEINTE NÚMERO 7)
                                                                                    # print(l)
                                                                                    try:
                                                                                        sub6 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/a")
                                                                                        s6 = sub6.text
                                                                                        _s6 = sub6.text

                                                                                        # print(s6)

                                                                                        principal6 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/a").get_attribute('onclick')
                                                                                        _principal6 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/a")

                                                                                        _p6 = _principal6.text

                                                                                        if (principal6 != ""):
                                                                                            # print("DESCARGAR TABLA")
                                                                                            _principal6.click()

                                                                                            # textOption.click()

                                                                                            frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                                                                            # print(len(frequency))

                                                                                            for r in range(len(frequency)):
                                                                                                frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                                                                # print("Cantidad: " + str(len(frequency)))
                                                                                                f = frequency[r].text
                                                                                                frequency[r].click()


                                                                                                # print(f)

                                                                                                freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                                                                if(len(freq) == 3):
                                                                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                                                                    for sd in range(len(initial)):
                                                                                                        initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                                        date1 = initial[sd].text

                                                                                                        initial[sd].click()

                                                                                                        currentUrl = driver.current_url

                                                                                                        dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                                        df = dataTable[0]
                                                                                                        del df["Sel."]

                                                                                                        # print('SUB 7: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                                                        df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')
                                                                                                        path6 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                                                                        tables(path6)
                                                                                                        # print("¡Guardado!")

                                                                                                else:
                                                                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                                    date1 = initial[0].text

                                                                                                    initial[0].click()

                                                                                                    final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                                                                    maxDate = len(final)
                                                                                                    date2 = final[maxDate-1].text

                                                                                                    final[maxDate-1].click()

                                                                                                    currentUrl = driver.current_url

                                                                                                    dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                                    df = dataTable[0]
                                                                                                    del df["Sel."]

                                                                                                    # print('SUB 7: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')


                                                                                                    df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                                                                                                    path6 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + str(_p6) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                                                                    tables(path6)
                                                                                                    # print("¡Guardado!")

                                                                                        else:
                                                                                            # print("CARPETA")

                                                                                            if(s6 != ""):
                                                                                                # number7.append(p+1)
                                                                                                # folder7.append(s6)
                                                                                                
                                                                                                # nsub7.append(number6)
                                                                                                # fsub7.append(number6)
                                                                                                
                                                                                                dix7 = diccionario7(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2, m+1, _s3, n+1, _s4, o+1, _s5, p+1, _s6)
                                                                                                dic7.append(dix7.copy())

                                                                                                s6 = str(p + 1)
                                                                                                # print(t)

                                                                                                if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6)):
                                                                                                    pass

                                                                                                else:
                                                                                                    os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6)

                                                                                            _principal6.click()

                                                                                            # number8 = []
                                                                                            # folder8 = []

                                                                                            # nsub8 = []
                                                                                            # fsub8 = []
                                                                                            
                                                                                            dic8 = []
                                                                                            
                                                                                            for q in range(20): # 20 # 8 (VEINTE NÚMERO 8)
                                                                                                # print(l)
                                                                                                try:
                                                                                                    sub7 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/ul/li[" + str(q + 1) +"]/a")
                                                                                                    s7 = sub7.text
                                                                                                    _s7 = sub7.text

                                                                                                    # print(s7)

                                                                                                    principal7 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/ul/li[" + str(q + 1) +"]/a").get_attribute('onclick')
                                                                                                    _principal7 = driver.find_element_by_xpath("/html/body/div[3]/nav/div[2]/ul/li[" + str(j + 1) +"]/ul/li[" + str(k + 1) +"]/ul/li[" + str(l + 1) +"]/ul/li[" + str(m + 1) +"]/ul/li[" + str(n + 1) +"]/ul/li[" + str(o + 1) +"]/ul/li[" + str(p + 1) +"]/ul/li[" + str(q + 1) +"]/a")

                                                                                                    _p7 = _principal7.text

                                                                                                    if (principal7 != ""):
                                                                                                        # print("DESCARGAR TABLA")
                                                                                                        _principal7.click()

                                                                                                        # textOption.click()

                                                                                                        frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")
                                                                                                        # print(len(frequency))

                                                                                                        for r in range(len(frequency)):
                                                                                                            frequency = driver.find_elements_by_xpath("//*[@id='cbFrecuencia']/option")

                                                                                                            # print("Cantidad: " + str(len(frequency)))
                                                                                                            f = frequency[r].text
                                                                                                            frequency[r].click()


                                                                                                            # print(f)

                                                                                                            freq = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div")

                                                                                                            if(len(freq) == 3):
                                                                                                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")

                                                                                                                for sd in range(len(initial)):
                                                                                                                    initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                                                    date1 = initial[sd].text

                                                                                                                    initial[sd].click()

                                                                                                                    currentUrl = driver.current_url

                                                                                                                    dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                                                    df = dataTable[0]
                                                                                                                    del df["Sel."]

                                                                                                                    # print('SUB 8: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')

                                                                                                                    df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx')
                                                                                                                    path7 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' - ' + str(f) + '.xlsx'
                                                                                                                    tables(path7)
                                                                                                                    # print("¡Guardado!")

                                                                                                            else:
                                                                                                                initial = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[1]/select/option")
                                                                                                                date1 = initial[0].text

                                                                                                                initial[0].click()

                                                                                                                final = driver.find_elements_by_xpath("/html/body/div[3]/div/form/div/div[2]/select/option")
                                                                                                                maxDate = len(final)
                                                                                                                date2 = final[maxDate-1].text

                                                                                                                final[maxDate-1].click()

                                                                                                                currentUrl = driver.current_url

                                                                                                                dataTable = pd.read_html(currentUrl, decimal=',', thousands='.')

                                                                                                                df = dataTable[0]
                                                                                                                del df["Sel."]

                                                                                                                # print('SUB 8: Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')


                                                                                                                df.transpose().to_excel('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx')
                                                                                                                path7 = '../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + str(_p7) + ' ' + str(date1) + ' a '  + str(date2) + ' - ' + str(f) + '.xlsx'
                                                                                                                tables(path7)
                                                                                                                # print("¡Guardado!")

                                                                                                    else:
                                                                                                        # number8.append(q+1)
                                                                                                        # folder8.append(s7)
                                                                                                        
                                                                                                        s7 = str(q + 1)

                                                                                                        # nsub8.append(number7)
                                                                                                        # fsub8.append(number7)
                                                                                                        
                                                                                                        dix8 = diccionario8(i+1, _t, j+1, _s, k+1, _s1, l+1, _s2, m+1, _s3, n+1, _s4, o+1, _s5, p+1, _s6, q+1, _s7)
                                                                                                        dic8.append(dix8.copy())
                                                                                                        # print("CARPETA")
                                                                                                        
                                                                                                        if (os.path.isdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + s7)):
                                                                                                            pass

                                                                                                        else:
                                                                                                            os.mkdir('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' + s7)

                                                                                                        _principal7.click()



                                                                                                except:
                                                                                                    pass
                                                                                            data8 = pd.DataFrame(dic8)
                                                                                            data8.to_csv('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' +  'Directorio.txt', index=False)
                                                                                            # df8.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + s6 + '/' +  'Directorio.txt', index=False)
                                                                                    except:
                                                                                        pass
                                                                                data7 = pd.DataFrame(dic7)
                                                                                data7.to_csv('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + 'Directorio.txt', index=False)
                                                                                # df7.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + s5 + '/' + 'Directorio.txt', index=False)

                                                                        except:
                                                                            pass

                                                                    data6 = pd.DataFrame(dic6)
                                                                    data6.to_csv('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + 'Directorio.txt', index=False)
                                                                    # df6.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + s4 + '/' + 'Directorio.txt', index=False)

                                                            except:
                                                                pass
                                                        data5 = pd.DataFrame(dic5)
                                                        data5.to_csv('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + 'Directorio.txt', index=False)
                                                        # df5.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + s3 + '/' + 'Directorio.txt', index=False)

                                                except:
                                                    pass
                                            data4 = pd.DataFrame(dic4)
                                            data4.to_csv('../' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + 'Directorio.txt', index=False)
                                            # df4.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + s2 + '/' + 'Directorio.txt', index=False)

                                    except:
                                        pass
                                data3 = pd.DataFrame(dic3)
                                data3.to_csv('../' + t + '/' + s + '/' + s1 + '/' + 'Directorio.txt', index=False)
                                # df3.to_csv('Files/' + t + '/' + s + '/' + s1 + '/' + 'Directorio.txt', index=False)
                        except:
                            pass
                    data2 = pd.DataFrame(dic2)
                    data2.to_csv('../' + t + '/' + s + '/' + 'Directorio.txt', index=False)
                    #df2.to_csv('Files/' + t + '/' + s + '/' + 'Directorio.txt', index=False)
        
            except:
                pass

        driver.close()
        driver = getDriver(url)

        data1 = pd.DataFrame(dic1)
        data1.to_csv('../' + t + '/' + 'Directorio.txt', index=False)

    data = pd.DataFrame(dic)
    data.to_csv('../Directorio.txt', index=False)

    driver.close()

# %%
def tables(path):
    
    df = pd.read_excel(path)
    df

    df.columns = df.iloc[0]
    df = df.drop(range(1))

    file = path
    mensual = file.find("Mensual")
    trimetre = file.find("Trimestral")
    diaria = file.find("Diaria")

    if(mensual > -1):

        df['Serie'] = df['Serie'].apply(lambda x: x.replace(".", "-"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Ene", "01-01"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Feb", "01-02"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Mar", "01-03"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Abr", "01-04"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("May", "01-05"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Jun", "01-06"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Jul", "01-07"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Ago", "01-08"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Sep", "01-09"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Oct", "01-10"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Nov", "01-11"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Dic", "01-12"))
        df

    elif(trimetre > -1):

        df['Serie'] = df['Serie'].apply(lambda x: x.replace(".", "-"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("IV", "01-10"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("III", "01-07"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("II", "01-04"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("I", "01-01"))
        df

    elif(diaria > -1):

        df['Serie'] = df['Serie'].apply(lambda x: x.replace(".", "-"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Ene", "01"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Feb", "02"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Mar", "03"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Abr", "04"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("May", "05"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Jun", "06"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Jul", "07"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Ago", "08"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Sep", "09"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Oct", "10"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Nov", "11"))
        df['Serie'] = df['Serie'].apply(lambda x: x.replace("Dic", "12"))
        df

    else:
        pass

    df.to_excel(path, index=False)

# %%
g = git.cmd.Git(git_dir)
g.pull()
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-30-3307c1e7aed5> in <module>
# ----> 1 repo = git.Repo.clone_from("https://github.com/Sud-Austral/banco_central", "C:/Users/datos/Documents/GitHub/banco_central")
#       2 repo
#
# C:\ProgramData\Anaconda3\lib\site-packages\git\repo\base.py in clone_from(cls, url, to_path, progress, env, multi_options, **kwargs)
#    1017         if env is not None:
#    1018             git.update_environment(**env)
# -> 1019         return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#    1020
#    1021     def archive(self, ostream, treeish=None, prefix=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\git\repo\base.py in _clone(cls, git, url, path, odb_default_type, progress, multi_options, **kwargs)
#     958             (stdout, stderr) = proc.communicate()
# ...

# %%
def guardarRepositorio():
    #Esta linea crea un objeto para manejar el repositorio alojado en la ruta
    #Correspondinete al argumento entregado en String
    repoLocal = git.Repo('C:/Users/datos/Documents/GitHub/banco_central/')  
    try:
        #Agrego todos los archivos nuevos
        repoLocal.git.add(".")
        #Hace el commit con un comentario sobre el origen del mismo y la hora
        repoLocal.git.commit(m='Actualización desde MV -datos-')
        #Apuntamos al gitHub (online)
        origin = repoLocal.remote(name='origin')
        #Se hace el push (enviar los archivos al repositorio online)
        origin.push()
        #Mensaje simpatico que todo salio bien
        print("Repositorio actualizado.")
    except:
        #Da un mensaje de error al fallar
        print("Error de GITHUB")    
    return

# %%
guardarRepositorio()
# Out:
# Error de GITHUB

# %%
while(True):
    
    descarga()
    guardarRepositorio()
    time.sleep(50400)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-16-7fc5dedcf9b6> in <module>
#       1 while(True):
#       2
# ----> 3     descarga()
#       4     guardarRepositorio()
#       5     time.sleep(50400)
#
# <ipython-input-13-501e1868e3fc> in descarga()
#    1037                 pass
#    1038
# -> 1039         driver.close()
#    1040         driver = getDriver(url)
#    1041
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...
